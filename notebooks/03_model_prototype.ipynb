# %% [markdown]
# # 03 — Model Prototype
#
# **Goal:** quickly iterate on architecture ideas before moving to `src/model.py`.

# %%
import torch
import torch.nn as nn
from pathlib import Path
import sys
sys.path.insert(0, '..')

from src.config import Config
from src.data import build_loaders
from src.utils import set_seed, get_device

cfg = Config.from_yaml('../configs/experiment_01.yaml')
set_seed(cfg.train.seed)
device = get_device(cfg.train.device)
print('Device:', device)

# %% [markdown]
# ## Prototype architecture

# %%
# TODO: define a quick prototype here, then migrate to src/model.py
# class ProtoModel(nn.Module):
#     ...

# %% [markdown]
# ## Quick training loop

# %%
# TODO: run a few epochs, check loss curves

# %% [markdown]
# ## Error analysis

# %%
# TODO: inspect worst predictions, confusion matrix, etc.
