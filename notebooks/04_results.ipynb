# %% [markdown]
# # 04 — Results & Analysis
#
# **Goal:** summarize final model performance, generate figures for report / paper.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.insert(0, '..')

from src.config import Config
from src.model import build_model
from src.data import build_loaders
from src.metrics import compute_metrics
from src.utils import get_device, load_checkpoint

cfg = Config.from_yaml('../configs/experiment_01.yaml')
device = get_device(cfg.train.device)

# %% [markdown]
# ## Load best checkpoint

# %%
# model = build_model(cfg.model).to(device)
# ckpt = load_checkpoint('../checkpoints/best.ckpt', device)
# model.load_state_dict(ckpt['model'])
# model.eval()

# %% [markdown]
# ## Metrics table

# %%
# TODO: run evaluation and display metrics
# results = {'Accuracy': ..., 'F1': ..., 'AUC': ...}
# pd.DataFrame([results])

# %% [markdown]
# ## Learning curves

# %%
# TODO: plot train/val loss & metric curves from W&B or saved CSV

# %% [markdown]
# ## Qualitative examples

# %%
# TODO: visualize predictions on interesting examples

# %% [markdown]
# ## Conclusions
#
# - TODO
